# %%
! python -m tf2onnx.convert \
  --opset 17 \
  --saved-model ../vendor/BirdNET-Analyzer/checkpoints/V2.2/BirdNET_GLOBAL_3K_V2.2_Model/ \
  --output ../data/models/onnx/test0.onnx \
  --continue_on_error
# Out:
# 2023-02-21 00:01:55.136334: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/Cellar/python@3.10/3.10.10/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py:126: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-02-21 00:02:00,728 - WARNING - ***IMPORTANT*** Installed protobuf is not cpp accelerated. Conversion will be extremely slow. See https://github.com/onnx/tensorflow-onnx/issues/1557
# 2023-02-21 00:02:00,730 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# ...

# %%
! python -m tf2onnx.convert \
  --opset 17 \
  --tflite ../vendor/BirdNET-Analyzer/checkpoints/V2.2/BirdNET_GLOBAL_3K_V2.2_Model_INT8.tflite \
  --output ../data/models/onnx/test1.onnx
# Out:
# 2023-02-21 00:23:47.777940: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/Cellar/python@3.10/3.10.10/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py:126: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-02-21 00:23:53,220 - WARNING - ***IMPORTANT*** Installed protobuf is not cpp accelerated. Conversion will be extremely slow. See https://github.com/onnx/tensorflow-onnx/issues/1557
# 2023-02-21 00:23:53,222 - INFO - Using tensorflow=2.11.0, onnx=1.13.0, tf2onnx=1.13.0/2c1db5
# ...

# %%
import onnxruntime as rt

sess = rt.InferenceSession("../data/models/onnx/test0.onnx")
input_name = sess.get_inputs()[0].name
# Out:
# ---------------------------------------------------------------------------
# InvalidGraph                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 import onnxruntime as rt
# ----> 3 sess = rt.InferenceSession("../data/models/onnx/test0.onnx")
#       4 input_name = sess.get_inputs()[0].name
#
# File ~/code/dsgt/birdclef-2023/venv/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:360, in InferenceSession.__init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     357 disabled_optimizers = kwargs["disabled_optimizers"] if "disabled_optimizers" in kwargs else None
#     359 try:
# --> 360     self._create_inference_session(providers, provider_options, disabled_optimizers)
#     361 except ValueError:
#     362     if self._enable_fallback:
#
# ...

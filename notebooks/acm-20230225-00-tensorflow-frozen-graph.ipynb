# %% [markdown]
# Before we get started, let's copy our copy of the relevant compiled tensorflow tools to the bin directory.
# This is compiled for the ubuntu 22.04 machines running x86_64.
# We should probably build a docker container to make these tools, but this one in particular takes 30 minutes to build on n2-standard-8.

# %%
tf_bin_path = "~/tensorflow/bazel-bin/"
data_bin_path = "../data/bin/linux/"
! mkdir -p {data_bin_path}
! cp -u {tf_bin_path}/tensorflow/tools/graph_transforms/transform_graph {data_bin_path}/transform_graph
! cp -u {tf_bin_path}/tensorflow/tools/graph_transforms/summarize_graph {data_bin_path}/summarize_graph
# also copy libtensorflow_framework.so.2 which is needed by both of the tools above
! cp -u {tf_bin_path}/tensorflow/libtensorflow_framework.so.2 {data_bin_path}/libtensorflow_framework.so.2
! gsutil rsync -r {data_bin_path} gs://birdclef-2023/data/bin/linux/
# Out:
# Building synchronization state...
# Starting synchronization...
# Copying file://../data/bin/linux/libtensorflow_framework.so.2 [Content-Type=application/octet-stream]...
# - [1 files][ 38.3 MiB/ 38.3 MiB]
# Operation completed over 1 objects/38.3 MiB.

# %%
# you might consider adding this directory to your PATH
tf_bin_path = "../data/bin/linux/"
model_path = "../vendor/BirdNET-Analyzer/checkpoints/V2.2/BirdNET_GLOBAL_3K_V2.2_Model/"
frozen_graph_v1 = "../data/models/birdnet-frozen-v1.pb"
opt_graph_v1 = "../data/models/birdnet-opt-v1.pb"
onnx_model_v1 = "../data/models/birdnet-onnx-v1.onnx"

! gsutil rsync -r gs://birdclef-2023/data/bin/linux/ {tf_bin_path}
! mkdir -p ../data/models
# Out:
# Building synchronization state...
# Starting synchronization...

# %% [markdown]
# - https://github.com/tensorflow/tensorflow/tree/master/tensorflow/tools/graph_transforms#using-the-graph-transform-tool
# - https://www.tensorflow.org/guide/saved_model
# - https://www.tensorflow.org/guide/saved_model#specifying_signatures_during_export
# - https://developer.arm.com/documentation/ecm0744361/ab/Determine-the-names-of-input-and-output-nodes

# %%
import tensorflow as tf
from tensorflow.python.framework.convert_to_constants import (
    convert_variables_to_constants_v2,
)

m = tf.saved_model.load(model_path)
frozen_func = convert_variables_to_constants_v2(m.signatures["basic"])
tf.io.write_graph(
    graph_or_graph_def=frozen_func.graph,
    logdir="./",
    name=frozen_graph_v1,
    as_text=False,
)
# Out:
# WARNING:absl:Importing a function (__inference_BLOCK_4-2_ACT_1_layer_call_and_return_conditional_losses_15267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-3_ACT_1_layer_call_and_return_conditional_losses_33161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-3_ACT_2_layer_call_and_return_conditional_losses_14525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-4_ACT_1_layer_call_and_return_conditional_losses_14681) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-4_ACT_2_layer_call_and_return_conditional_losses_14723) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-2_ACT_2_layer_call_and_return_conditional_losses_14327) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-2_ACT_2_layer_call_and_return_conditional_losses_32783) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-4_ACT_1_layer_call_and_return_conditional_losses_13993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-3_ACT_2_layer_call_and_return_conditional_losses_30727) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-5_SE_CONV_1_layer_call_and_return_conditional_losses_14953) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_1-3_ACT_1_layer_call_and_return_conditional_losses_28018) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-2_ACT_2_layer_call_and_return_conditional_losses_30210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-1_ACT_1_layer_call_and_return_conditional_losses_13695) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-3_ACT_2_layer_call_and_return_conditional_losses_15507) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-2_SE_CONV_1_layer_call_and_return_conditional_losses_14359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_25336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-1_SE_CONV_1_layer_call_and_return_conditional_losses_29744) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-1_ACT_1_layer_call_and_return_conditional_losses_15077) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_basic_5289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-4_ACT_1_layer_call_and_return_conditional_losses_33678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-4_ACT_2_layer_call_and_return_conditional_losses_15705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-4_SE_CONV_1_layer_call_and_return_conditional_losses_33856) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-2_SE_CONV_1_layer_call_and_return_conditional_losses_15341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_1-3_ACT_1_layer_call_and_return_conditional_losses_13593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-3_SE_CONV_1_layer_call_and_return_conditional_losses_15539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_7115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-3_ACT_1_layer_call_and_return_conditional_losses_13891) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-1_ACT_2_layer_call_and_return_conditional_losses_32278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-5_ACT_1_layer_call_and_return_conditional_losses_14879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-3_ACT_1_layer_call_and_return_conditional_losses_15465) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-1_ACT_1_layer_call_and_return_conditional_losses_29566) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_1-2_ACT_1_layer_call_and_return_conditional_losses_27706) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-1_ACT_1_layer_call_and_return_conditional_losses_28330) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-1_ACT_2_layer_call_and_return_conditional_losses_15119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-3_SE_CONV_1_layer_call_and_return_conditional_losses_33339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_1-1_ACT_1_layer_call_and_return_conditional_losses_13397) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-1_ACT_1_layer_call_and_return_conditional_losses_32139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-2_SE_CONV_1_layer_call_and_return_conditional_losses_30249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-1_ACT_2_layer_call_and_return_conditional_losses_29705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-1_SE_CONV_1_layer_call_and_return_conditional_losses_14169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-5_ACT_2_layer_call_and_return_conditional_losses_31761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-4_ACT_1_layer_call_and_return_conditional_losses_31105) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-2_ACT_1_layer_call_and_return_conditional_losses_28630) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_1-1_ACT_1_layer_call_and_return_conditional_losses_27406) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-2_ACT_1_layer_call_and_return_conditional_losses_30071) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-5_SE_CONV_1_layer_call_and_return_conditional_losses_31800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-3_SE_CONV_1_layer_call_and_return_conditional_losses_14557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-4_SE_CONV_1_layer_call_and_return_conditional_losses_14755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-3_ACT_1_layer_call_and_return_conditional_losses_14483) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-4_ACT_1_layer_call_and_return_conditional_losses_15663) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_26662) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-2_ACT_1_layer_call_and_return_conditional_losses_32644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-2_ACT_2_layer_call_and_return_conditional_losses_15309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-3_ACT_1_layer_call_and_return_conditional_losses_30588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-2_ACT_1_layer_call_and_return_conditional_losses_14285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-4_ACT_2_layer_call_and_return_conditional_losses_31244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-1_SE_CONV_1_layer_call_and_return_conditional_losses_15151) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-5_ACT_1_layer_call_and_return_conditional_losses_31622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_1-2_ACT_1_layer_call_and_return_conditional_losses_13491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-3_ACT_1_layer_call_and_return_conditional_losses_28942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-4_ACT_1_layer_call_and_return_conditional_losses_29254) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-4_ACT_2_layer_call_and_return_conditional_losses_33817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-3_ACT_2_layer_call_and_return_conditional_losses_33300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-3_SE_CONV_1_layer_call_and_return_conditional_losses_30766) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-1_SE_CONV_1_layer_call_and_return_conditional_losses_32317) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-4_SE_CONV_1_layer_call_and_return_conditional_losses_31283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-5_ACT_2_layer_call_and_return_conditional_losses_14921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_2-2_ACT_1_layer_call_and_return_conditional_losses_13789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-1_ACT_1_layer_call_and_return_conditional_losses_14095) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_3-1_ACT_2_layer_call_and_return_conditional_losses_14137) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-4_SE_CONV_1_layer_call_and_return_conditional_losses_15737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_BLOCK_4-2_SE_CONV_1_layer_call_and_return_conditional_losses_32822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# './../data/models/birdnet-frozen-v1.pb'

# %%
! {tf_bin_path}/transform_graph \
    --in_graph={frozen_graph_v1} \
    --out_graph={opt_graph_v1} \
    --inputs='inputs:0' \
    --transforms=' \
        remove_nodes(op=Identity, op=CheckNumerics) \
        fold_old_batch_norms \
    '

# %%
! {tf_bin_path}/summarize_graph \
    --in_graph={opt_graph_v1} \
    --print_structure=true
# Out:
# Found 1 possible inputs: (name=inputs, type=float(1), shape=[?,144000])
# No variables spotted.
# Found 1 possible outputs: (name=StatefulPartitionedCall/model/CLASS_DENSE_1/BiasAdd, op=Add)
# Found 5488973 (5.49M) const parameters, 0 (0) variable parameters, and 246 control_edges
# Op types used: 363 Const, 53 Conv2D, 49 Mul, 45 FusedBatchNormV3, 43 Sigmoid, 34 IdentityN, 17 AddV2, 15 Pack, 14 Reshape, 12 StridedSlice, 10 Mean, 10 Shape, 9 DepthwiseConv2dNative, 7 Sub, 4 FloorDiv, 4 ConcatV2, 4 Cast, 4 Range, 3 Relu, 3 RealDiv, 2 Pow, 2 Add, 1 RFFT, 1 SplitV, 1 Placeholder, 1 Transpose, 1 NoOp, 1 Min, 1 Maximum, 1 MaxPool, 1 Max, 1 MatMul, 1 GatherV2, 1 FloorMod, 1 Fill, 1 ExpandDims, 1 Exp, 1 Cos, 1 AvgPool
# To use with tensorflow/tools/benchmark:benchmark_model try these arguments:
# bazel run tensorflow/tools/benchmark:benchmark_model -- --graph=../data/models/birdnet-opt-v1.pb --show_flops --input_layer=inputs --input_layer_type=float --input_layer_shape=-1,144000 --output_layer=StatefulPartitionedCall/model/CLASS_DENSE_1/BiasAdd
# unknown_244 (Const): [], value=Tensor<type: float shape: [3337] values: -0.0191420149 -0.141979232 -0.0990731046...>
# unknown_243 (Const): [], value=Tensor<type: float shape: [320,3337] values: [-0.663574278 -0.562552214 0.138601318...]...>
# unknown_242 (Const): [], value=Tensor<type: float shape: [320] values: 256.795197 234.595764 193.480408...>
# unknown_241 (Const): [], value=Tensor<type: float shape: [320] values: -6.11930799 -2.27974749 -2.46129036...>
# unknown_240 (Const): [], value=Tensor<type: float shape: [320] values: 0.289544731 0.182339266 0.123041883...>
# unknown_239 (Const): [], value=Tensor<type: float shape: [320] values: 1.99149168 2.22547 2.17423844...>
# unknown_238 (Const): [], value=Tensor<type: float shape: [4,3,224,320] values: [[[0.327389568 0.168706521 -0.0602678657...]]]...>
# unknown_237 (Const): [], value=Tensor<type: float shape: [224] values: 6.12629557 5.59307909 8.88578...>
# unknown_236 (Const): [], value=Tensor<type: float shape: [224] values: 4.76441073e-06 1.89230668e-05 -1.05761201e-05...>
# unknown_235 (Const): [], value=Tensor<type: float shape: [224] values: 0.507024944 0.509908915 0.384418905...>
# unknown_234 (Const): [], value=Tensor<type: float shape: [224] values: 0.936352134 0.843912661 1.23281646...>
# unknown_233 (Const): [], value=Tensor<type: float shape: [224] values: 9.79859 9.55825329 9.21818447...>
# unknown_232 (Const): [], value=Tensor<type: float shape: [224] values: 0.651712477 0.313388824 0.244526058...>
# unknown_231 (Const): [], value=Tensor<type: float shape: [224] values: 3.87015916e-06 6.1614669e-06 -1.69970508e-06...>
# unknown_230 (Const): [], value=Tensor<type: float shape: [224] values: 1.74373293 1.73772573 1.57193208...>
# unknown_229 (Const): [], value=Tensor<type: float shape: [1,1,896,224] values: [[[0.27246964 0.127778873 -0.225545213...]]]...>
# unknown_228 (Const): [], value=Tensor<type: float shape: [1,1,56,896] values: [[[-0.25102824 -0.0483289212 -0.206507429...]]]...>
# unknown_227 (Const): [], value=Tensor<type: float shape: [1,1,896,56] values: [[[0.501525044 -0.328775525 -0.191903874...]]]...>
# unknown_226 (Const): [], value=Tensor<type: float shape: [896] values: 0.262508452 0.00141097209 0.115004912...>
# unknown_225 (Const): [], value=Tensor<type: float shape: [896] values: 0.0818121 -0.0882265344 -0.0914198458...>
# unknown_224 (Const): [], value=Tensor<type: float shape: [896] values: -0.100254126 0.045885548 -0.344496906...>
# unknown_223 (Const): [], value=Tensor<type: float shape: [896] values: 0.54118818 0.561018407 0.804562569...>
# unknown_222 (Const): [], value=Tensor<type: float shape: [3,3,896,1] values: [[[-0.157377884][0.0572717711][-0.0618366711]]]...>
# unknown_221 (Const): [], value=Tensor<type: float shape: [896] values: 49.3426933 43.8859978 23.7625389...>
# unknown_220 (Const): [], value=Tensor<type: float shape: [896] values: -0.000237403801 8.18486078e-05 0.000108463406...>
# unknown_219 (Const): [], value=Tensor<type: float shape: [896] values: -0.201497644 -0.93611145 -0.309345245...>
# unknown_218 (Const): [], value=Tensor<type: float shape: [896] values: 1.42368639 0.673146367 1.24288654...>
# unknown_217 (Const): [], value=Tensor<type: float shape: [1,1,224,896] values: [[[0.215597332 0.262965947 0.214630127...]]]...>
# unknown_216 (Const): [], value=Tensor<type: float shape: [224] values: 5.47905779 4.6566534 5.34367228...>
# unknown_215 (Const): [], value=Tensor<type: float shape: [224] values: 0.0752443 -0.10685236 0.0317501053...>
# unknown_214 (Const): [], value=Tensor<type: float shape: [224] values: 4.97782958e-06 3.22755591e-06 -2.26386942e-06...>
# unknown_213 (Const): [], value=Tensor<type: float shape: [224] values: 0.938786447 0.826061904 0.863758504...>
# unknown_212 (Const): [], value=Tensor<type: float shape: [1,1,896,224] values: [[[-0.368781388 0.169524416 -0.106056407...]]]...>
# unknown_211 (Const): [], value=Tensor<type: float shape: [1,1,56,896] values: [[[0.244073823 0.0928172693 -0.0667013153...]]]...>
# unknown_210 (Const): [], value=Tensor<type: float shape: [1,1,896,56] values: [[[-0.20154877 0.0193051137 0.965217233...]]]...>
# unknown_209 (Const): [], value=Tensor<type: float shape: [896] values: 0.0205787979 0.194083244 0.38155067...>
# unknown_208 (Const): [], value=Tensor<type: float shape: [896] values: 0.06294664 -0.170425937 -0.204842418...>
# unknown_207 (Const): [], value=Tensor<type: float shape: [896] values: -0.00564211467 -0.160081089 -0.265904546...>
# unknown_206 (Const): [], value=Tensor<type: float shape: [896] values: 0.396376699 0.961722434 0.8009516...>
# unknown_205 (Const): [], value=Tensor<type: float shape: [3,3,896,1] values: [[[-0.193185911][0.312960267][-0.0267973728]]]...>
# unknown_204 (Const): [], value=Tensor<type: float shape: [896] values: 14.211669 66.7573471 13.9687223...>
# unknown_203 (Const): [], value=Tensor<type: float shape: [896] values: -1.42325634e-05 -7.23819758e-05 -6.61815793e-05...>
# unknown_202 (Const): [], value=Tensor<type: float shape: [896] values: -0.470376432 -0.488352239 -0.0626808256...>
# unknown_201 (Const): [], value=Tensor<type: float shape: [896] values: 0.886135101 1.55503368 1.07820034...>
# unknown_200 (Const): [], value=Tensor<type: float shape: [1,1,224,896] values: [[[0.226856604 -0.0371234864 0.120986521...]]]...>
# unknown_199 (Const): [], value=Tensor<type: float shape: [224] values: 6.460145 5.83891344 5.34272528...>
# unknown_198 (Const): [], value=Tensor<type: float shape: [224] values: 0.326885521 -0.146229669 -0.377017051...>
# unknown_197 (Const): [], value=Tensor<type: float shape: [224] values: 1.32729224e-06 1.07108042e-06 -6.85289e-06...>
# unknown_196 (Const): [], value=Tensor<type: float shape: [224] values: 0.825664341 0.74643296 0.669682622...>
# unknown_195 (Const): [], value=Tensor<type: float shape: [1,1,896,224] values: [[[0.193968669 -0.341957271 0.0410528108...]]]...>
# unknown_194 (Const): [], value=Tensor<type: float shape: [1,1,56,896] values: [[[-0.289916575 0.339850396 -0.341427326...]]]...>
# unknown_193 (Const): [], value=Tensor<type: float shape: [1,1,896,56] values: [[[0.329476774 -0.339646429 0.0187124852...]]]...>
# unknown_192 (Const): [], value=Tensor<type: float shape: [896] values: 0.0242645647 0.180745244 0.593420684...>
# unknown_191 (Const): [], value=Tensor<type: float shape: [896] values: -0.0752661228 -0.644926667 0.0912220255...>
# unknown_190 (Const): [], value=Tensor<type: float shape: [896] values: 0.024149308 0.0585802607 -0.0320808887...>
# unknown_189 (Const): [], value=Tensor<type: float shape: [896] values: 0.340933353 0.382203281 0.835846186...>
# unknown_188 (Const): [], value=Tensor<type: float shape: [3,3,896,1] values: [[[-0.020493729][-0.0495228395][-0.0366055034]]]...>
# unknown_187 (Const): [], value=Tensor<type: float shape: [896] values: 10.7227669 26.8951893 14.728982...>
# unknown_186 (Const): [], value=Tensor<type: float shape: [896] values: 9.83455175e-06 9.37173536e-06 -2.05372703e-06...>
# unknown_185 (Const): [], value=Tensor<type: float shape: [896] values: -0.661817372 1.21771693 -0.370062172...>
# unknown_184 (Const): [], value=Tensor<type: float shape: [896] values: 0.959611475 1.28467929 1.80458069...>
# unknown_183 (Const): [], value=Tensor<type: float shape: [1,1,224,896] values: [[[0.0293685421 -0.269529611 0.0931101143...]]]...>
# unknown_182 (Const): [], value=Tensor<type: float shape: [224] values: 8.50703335 7.27810335 9.84166622...>
# unknown_181 (Const): [], value=Tensor<type: float shape: [224] values: 0.412980914 -0.305923939 -0.960492551...>
# unknown_180 (Const): [], value=Tensor<type: float shape: [224] values: -5.41493091e-06 8.47458887e-06 2.53182378e-07...>
# unknown_179 (Const): [], value=Tensor<type: float shape: [224] values: 1.04986334 0.95139873 1.10690928...>
# unknown_178 (Const): [], value=Tensor<type: float shape: [1,1,896,224] values: [[[-0.14300324 0.573495 0.397022098...]]]...>
# unknown_177 (Const): [], value=Tensor<type: float shape: [1,1,56,896] values: [[[-0.14576748 -0.0574014857 0.0196636189...]]]...>
# unknown_176 (Const): [], value=Tensor<type: float shape: [1,1,896,56] values: [[[0.0613442 -0.23065564 -0.184517369...]]]...>
# unknown_175 (Const): [], value=Tensor<type: float shape: [896] values: 0.203245282 0.000332123251 0.000761273201...>
# unknown_174 (Const): [], value=Tensor<type: float shape: [896] values: -0.270287842 -0.0844664 -0.0702956095...>
# unknown_173 (Const): [], value=Tensor<type: float shape: [896] values: 0.233576581 0.00317915319 -0.233091906...>
# unknown_172 (Const): [], value=Tensor<type: float shape: [896] values: 0.925041258 0.840271175 0.747719884...>
# unknown_171 (Const): [], value=Tensor<type: float shape: [3,3,896,1] values: [[[0.313683867][-0.0313351862][0.19614248]]]...>
# unknown_170 (Const): [], value=Tensor<type: float shape: [896] values: 112.150322 68.9085693 113.531105...>
# unknown_169 (Const): [], value=Tensor<type: float shape: [896] values: 1.10677684e-05 7.64055949e-05 3.1527652e-05...>
# unknown_168 (Const): [], value=Tensor<type: float shape: [896] values: -0.844256043 -0.930836201 -0.764753938...>
# unknown_167 (Const): [], value=Tensor<type: float shape: [896] values: 0.926220357 0.57016468 0.401993334...>
# unknown_166 (Const): [], value=Tensor<type: float shape: [1,1,128,896] values: [[[0.165994108 0.149425641 -0.148558959...]]]...>
# unknown_165 (Const): [], value=Tensor<type: float shape: [128] values: 3.46098661 2.50185204 2.43322968...>
# unknown_164 (Const): [], value=Tensor<type: float shape: [128] values: 0.0318973064 -0.260509878 0.072786577...>
# unknown_163 (Const): [], value=Tensor<type: float shape: [128] values: 4.09267932e-06 -1.19793481e-06 5.14478825e-06...>
# unknown_162 (Const): [], value=Tensor<type: float shape: [128] values: 1.17082584 1.04749346 0.918514967...>
# unknown_161 (Const): [], value=Tensor<type: float shape: [1,1,512,128] values: [[[0.221963376 -0.0479359403 -0.00521957967...]]]...>
# unknown_160 (Const): [], value=Tensor<type: float shape: [1,1,32,512] values: [[[-0.279657513 -0.273851186 0.269947827...]]]...>
# unknown_159 (Const): [], value=Tensor<type: float shape: [1,1,512,32] values: [[[-0.0815686807 0.299476862 -0.0516558476...]]]...>
# unknown_158 (Const): [], value=Tensor<type: float shape: [512] values: 0.00621392531 0.225919545 0.10229551...>
# unknown_157 (Const): [], value=Tensor<type: float shape: [512] values: 0.0123374788 -0.0265207794 0.102206171...>
# unknown_156 (Const): [], value=Tensor<type: float shape: [512] values: -0.596776307 0.0159350391 0.194908842...>
# unknown_155 (Const): [], value=Tensor<type: float shape: [512] values: 1.01073766 0.336915314 0.433729768...>
# unknown_154 (Const): [], value=Tensor<type: float shape: [3,3,512,1] values: [[[-0.0673916116][0.0217399877][0.0576211214]]]...>
# unknown_153 (Const): [], value=Tensor<type: float shape: [512] values: 31.3021564 40.7079926 58.9483528...>
# unknown_152 (Const): [], value=Tensor<type: float shape: [512] values: -4.99890957e-05 -3.02890362e-06 -9.63833882e-05...>
# unknown_151 (Const): [], value=Tensor<type: float shape: [512] values: -0.0380779654 -0.207867324 -0.328269273...>
# unknown_150 (Const): [], value=Tensor<type: float shape: [512] values: 0.309408724 1.51460254 1.72241521...>
# unknown_149 (Const): [], value=Tensor<type: float shape: [1,1,128,512] values: [[[-0.268131435 0.165381908 -0.0870989263...]]]...>
# unknown_148 (Const): [], value=Tensor<type: float shape: [128] values: 3.30573297 4.67896891 4.96729898...>
# unknown_147 (Const): [], value=Tensor<type: float shape: [128] values: 0.272193044 -0.0970988944 -0.233079359...>
# unknown_146 (Const): [], value=Tensor<type: float shape: [128] values: 5.00882788e-06 -9.51335733e-06 1.39683907e-05...>
# unknown_145 (Const): [], value=Tensor<type: float shape: [128] values: 0.966650486 1.11295283 1.10820389...>
# unknown_144 (Const): [], value=Tensor<type: float shape: [1,1,512,128] values: [[[-0.258921921 -0.957146943 -0.245727137...]]]...>
# unknown_143 (Const): [], value=Tensor<type: float shape: [1,1,32,512] values: [[[0.13217929 -0.262901396 0.0846735612...]]]...>
# unknown_142 (Const): [], value=Tensor<type: float shape: [1,1,512,32] values: [[[-0.405839 -0.055245664 0.152252078...]]]...>
# unknown_141 (Const): [], value=Tensor<type: float shape: [512] values: 0.654183 0.0103518898 0.084362...>
# unknown_140 (Const): [], value=Tensor<type: float shape: [512] values: -0.0986791775 0.0949240178 -0.0131041864...>
# unknown_139 (Const): [], value=Tensor<type: float shape: [512] values: -0.44764486 -0.240612134 -0.192683309...>
# unknown_138 (Const): [], value=Tensor<type: float shape: [512] values: 1.62731564 0.699796796 0.750510454...>
# unknown_137 (Const): [], value=Tensor<type: float shape: [3,3,512,1] values: [[[-0.0574132][0.0277042557][0.0178262908]]]...>
# unknown_136 (Const): [], value=Tensor<type: float shape: [512] values: 75.4473953 29.2152042 21.0187092...>
# unknown_135 (Const): [], value=Tensor<type: float shape: [512] values: 8.14070809e-05 -7.68778627e-05 0.000121228892...>
# unknown_134 (Const): [], value=Tensor<type: float shape: [512] values: -0.318835467 -0.378007352 -0.630101442...>
# unknown_133 (Const): [], value=Tensor<type: float shape: [512] values: 1.19924212 0.526127338 1.19496989...>
# unknown_132 (Const): [], value=Tensor<type: float shape: [1,1,128,512] values: [[[0.558560371 -0.331930518 0.0412835591...]]]...>
# unknown_131 (Const): [], value=Tensor<type: float shape: [128] values: 4.94385 5.43417883 4.23100185...>
# unknown_130 (Const): [], value=Tensor<type: float shape: [128] values: 0.19761464 0.256303936 0.140774131...>
# unknown_129 (Const): [], value=Tensor<type: float shape: [128] values: 1.25632851e-05 -5.8671626e-06 1.11828085e-05...>
# unknown_128 (Const): [], value=Tensor<type: float shape: [128] values: 0.946011066 1.00546837 0.653112292...>
# unknown_127 (Const): [], value=Tensor<type: float shape: [1,1,512,128] values: [[[-0.559285581 0.0146419052 0.606434226...]]]...>
# unknown_126 (Const): [], value=Tensor<type: float shape: [1,1,32,512] values: [[[0.196216658 -0.120854907 -0.259520441...]]]...>
# unknown_125 (Const): [], value=Tensor<type: float shape: [1,1,512,32] values: [[[-0.0593199581 0.123461269 0.224329248...]]]...>
# unknown_124 (Const): [], value=Tensor<type: float shape: [512] values: 0.0109494589 0.0176946186 0.0606579818...>
# unknown_123 (Const): [], value=Tensor<type: float shape: [512] values: 0.0125128943 0.0552015528 -0.0690638721...>
# unknown_122 (Const): [], value=Tensor<type: float shape: [512] values: -0.234877735 -0.0566980317 -0.374001056...>
# unknown_121 (Const): [], value=Tensor<type: float shape: [512] values: 0.662949 0.476274878 0.850863397...>
# unknown_120 (Const): [], value=Tensor<type: float shape: [3,3,512,1] values: [[[0.108076595][0.0453895107][0.0190143138]]]...>
# unknown_119 (Const): [], value=Tensor<type: float shape: [512] values: 33.7799416 12.5435314 15.2927189...>
# unknown_118 (Const): [], value=Tensor<type: float shape: [512] values: -4.81993156e-05 4.78033326e-05 4.22008952e-06...>
# unknown_117 (Const): [], value=Tensor<type: float shape: [512] values: 0.0816019 0.274037451 0.486160755...>
# unknown_116 (Const): [], value=Tensor<type: float shape: [512] values: 0.939434052 0.54969728 0.515172601...>
# unknown_115 (Const): [], value=Tensor<type: float shape: [1,1,128,512] values: [[[0.307741761 0.0439058132 0.0832265392...]]]...>
# unknown_114 (Const): [], value=Tensor<type: float shape: [128] values: 3.35112262 2.89874196 4.51241732...>
# unknown_113 (Const): [], value=Tensor<type: float shape: [128] values: 0.0742153 0.380395502 0.115444787...>
# unknown_112 (Const): [], value=Tensor<type: float shape: [128] values: 7.358115e-06 -2.2876734e-06 9.54414531e-07...>
# unknown_111 (Const): [], value=Tensor<type: float shape: [128] values: 0.839973509 0.768742144 0.794937491...>
# unknown_110 (Const): [], value=Tensor<type: float shape: [1,1,512,128] values: [[[-0.205404311 0.192143381 -0.426653...]]]...>
# unknown_109 (Const): [], value=Tensor<type: float shape: [1,1,32,512] values: [[[0.182055056 -0.0721257403 0.0537579618...]]]...>
# unknown_108 (Const): [], value=Tensor<type: float shape: [1,1,512,32] values: [[[0.37551114 0.349432945 -0.378296912...]]]...>
# unknown_107 (Const): [], value=Tensor<type: float shape: [512] values: 0.0099046547 0.0950641185 0.496941119...>
# unknown_106 (Const): [], value=Tensor<type: float shape: [512] values: -0.0170199927 0.0234866943 -0.085499756...>
# unknown_105 (Const): [], value=Tensor<type: float shape: [512] values: -0.255706549 -0.203891024 -0.269659162...>
# unknown_104 (Const): [], value=Tensor<type: float shape: [512] values: 0.588789046 0.682861626 1.25435674...>
# unknown_103 (Const): [], value=Tensor<type: float shape: [3,3,512,1] values: [[[0.259477764][-0.0992103294][0.0360947028]]]...>
# unknown_102 (Const): [], value=Tensor<type: float shape: [512] values: 21.1636906 9.83970547 31.8353939...>
# unknown_101 (Const): [], value=Tensor<type: float shape: [512] values: 3.00045485e-06 2.41622893e-05 -4.82942096e-06...>
# unknown_100 (Const): [], value=Tensor<type: float shape: [512] values: -0.165260375 -0.529412 -0.0389320627...>
# unknown_99 (Const): [], value=Tensor<type: float shape: [512] values: 1.0844909 0.957234621 0.723279536...>
# unknown_98 (Const): [], value=Tensor<type: float shape: [1,1,128,512] values: [[[-0.395741105 0.0184004363 0.436068505...]]]...>
# unknown_97 (Const): [], value=Tensor<type: float shape: [128] values: 8.24600887 8.48245335 12.9576254...>
# unknown_96 (Const): [], value=Tensor<type: float shape: [128] values: -0.867971897 -0.336623877 0.105143607...>
# unknown_95 (Const): [], value=Tensor<type: float shape: [128] values: 4.01758e-06 -1.72300752e-05 2.14498014e-05...>
# unknown_94 (Const): [], value=Tensor<type: float shape: [128] values: 1.19481432 1.22306299 1.52849126...>
# unknown_93 (Const): [], value=Tensor<type: float shape: [1,1,512,128] values: [[[0.165953606 0.448597372 0.253403217...]]]...>
# unknown_92 (Const): [], value=Tensor<type: float shape: [1,1,32,512] values: [[[0.0587211847 0.143877476 0.155125335...]]]...>
# unknown_91 (Const): [], value=Tensor<type: float shape: [1,1,512,32] values: [[[-0.159407437 0.284770697 -0.146846369...]]]...>
# unknown_90 (Const): [], value=Tensor<type: float shape: [512] values: 0.0530836172 0.0553563721 0.155163631...>
# unknown_89 (Const): [], value=Tensor<type: float shape: [512] values: 0.128802434 -0.183447212 -0.0402512...>
# unknown_88 (Const): [], value=Tensor<type: float shape: [512] values: 0.508705616 0.233453721 -0.322241127...>
# unknown_87 (Const): [], value=Tensor<type: float shape: [512] values: 0.403838 0.726751924 0.725370467...>
# unknown_86 (Const): [], value=Tensor<type: float shape: [3,3,512,1] values: [[[0.00426108856][0.187966466][0.0800039917]]]...>
# unknown_85 (Const): [], value=Tensor<type: float shape: [512] values: 40.9248314 43.6178894 45.1275215...>
# unknown_84 (Const): [], value=Tensor<type: float shape: [512] values: 0.722351909 0.52393955 -1.8848635...>
# unknown_83 (Const): [], value=Tensor<type: float shape: [512] values: 0.0254789572 -0.718175 1.0117892...>
# unknown_82 (Const): [], value=Tensor<type: float shape: [512] values: 0.809217393 0.707967341 0.817903638...>
# unknown_81 (Const): [], value=Tensor<type: float shape: [1,1,96,512] values: [[[0.243963555 0.194127381 -0.262234598...]]]...>
# unknown_80 (Const): [], value=Tensor<type: float shape: [96] values: 3.46392632 2.88924909 2.25954652...>
# unknown_79 (Const): [], value=Tensor<type: float shape: [96] values: -0.123652734 -0.142573595 0.0128893927...>
# unknown_78 (Const): [], value=Tensor<type: float shape: [96] values: 1.99909937e-06 1.51846154e-06 -5.37523704e-07...>
# unknown_77 (Const): [], value=Tensor<type: float shape: [96] values: 1.27137649 1.48503304 1.23627651...>
# unknown_76 (Const): [], value=Tensor<type: float shape: [1,1,192,96] values: [[[-0.00925871264 -0.117740899 0.187405318...]]]...>
# unknown_75 (Const): [], value=Tensor<type: float shape: [192] values: 329.652252 200.970764 160.795792...>
# unknown_74 (Const): [], value=Tensor<type: float shape: [192] values: -17.2399521 2.17969561 8.73835087...>
# unknown_73 (Const): [], value=Tensor<type: float shape: [192] values: -0.425777227 -0.626675367 0.250154436...>
# unknown_72 (Const): [], value=Tensor<type: float shape: [192] values: 0.847773671 0.868433475 0.686083436...>
# unknown_71 (Const): [], value=Tensor<type: float shape: [3,3,96,192] values: [[[-0.214971527 0.022663312 -0.0431018...]]]...>
# unknown_70 (Const): [], value=Tensor<type: float shape: [96] values: 2.74102545 3.44306231 1.51323104...>
# unknown_69 (Const): [], value=Tensor<type: float shape: [96] values: 0.68115 0.837442517 -0.323164493...>
# unknown_68 (Const): [], value=Tensor<type: float shape: [96] values: 0.0660913065 -0.370748401 -0.525611579...>
# unknown_67 (Const): [], value=Tensor<type: float shape: [96] values: 1.09338927 1.38329291 0.891733706...>
# unknown_66 (Const): [], value=Tensor<type: float shape: [1,1,192,96] values: [[[0.0706531405 -0.341568649 0.158613414...]]]...>
# unknown_65 (Const): [], value=Tensor<type: float shape: [192] values: 140.456589 118.038567 70.9883728...>
# unknown_64 (Const): [], value=Tensor<type: float shape: [192] values: 6.34927 4.93796444 -2.61526728...>
# unknown_63 (Const): [], value=Tensor<type: float shape: [192] values: -0.672120214 -0.343861 -0.177672416...>
# unknown_62 (Const): [], value=Tensor<type: float shape: [192] values: 0.921066225 0.904044926 0.735677302...>
# unknown_61 (Const): [], value=Tensor<type: float shape: [3,3,96,192] values: [[[-0.284534425 -0.211959854 -0.0243010819...]]]...>
# unknown_60 (Const): [], value=Tensor<type: float shape: [96] values: 2.54694939 3.85156393 4.28796577...>
# unknown_59 (Const): [], value=Tensor<type: float shape: [96] values: -0.0246525928 -0.0501743108 1.03666759...>
# unknown_58 (Const): [], value=Tensor<type: float shape: [96] values: 0.0183773469 0.0114825936 0.257290959...>
# unknown_57 (Const): [], value=Tensor<type: float shape: [96] values: 0.819963813 1.12682569 0.996156454...>
# unknown_56 (Const): [], value=Tensor<type: float shape: [1,1,192,96] values: [[[-0.299219936 -0.0723683313 -0.0881081074...]]]...>
# unknown_55 (Const): [], value=Tensor<type: float shape: [192] values: 112.656303 81.1119537 90.0608673...>
# unknown_54 (Const): [], value=Tensor<type: float shape: [192] values: -6.7467041 -8.59693432 -17.212347...>
# unknown_53 (Const): [], value=Tensor<type: float shape: [192] values: -0.27263692 -0.64840579 -0.496610492...>
# unknown_52 (Const): [], value=Tensor<type: float shape: [192] values: 1.28344488 1.31140053 1.05855751...>
# unknown_51 (Const): [], value=Tensor<type: float shape: [3,3,96,192] values: [[[0.258256853 -0.085049957 0.276124835...]]]...>
# unknown_50 (Const): [], value=Tensor<type: float shape: [96] values: 5.83166027 6.09098721 7.45372295...>
# unknown_49 (Const): [], value=Tensor<type: float shape: [96] values: 1.1975584 2.41808176 2.46470571...>
# unknown_48 (Const): [], value=Tensor<type: float shape: [96] values: -0.153015867 1.07425189 0.502800345...>
# unknown_47 (Const): [], value=Tensor<type: float shape: [96] values: 1.01273715 0.838171661 1.01029146...>
# unknown_46 (Const): [], value=Tensor<type: float shape: [1,1,192,96] values: [[[-0.343984962 0.391965449 -0.200002506...]]]...>
# unknown_45 (Const): [], value=Tensor<type: float shape: [192] values: 206.763138 156.240387 176.204559...>
# unknown_44 (Const): [], value=Tensor<type: float shape: [192] values: -50.3408051 -19.4256573 -34.1390457...>
# unknown_43 (Const): [], value=Tensor<type: float shape: [192] values: 0.484948277 -0.128194392 0.164522856...>
# unknown_42 (Const): [], value=Tensor<type: float shape: [192] values: 0.969928 0.87049067 1.01976693...>
# unknown_41 (Const): [], value=Tensor<type: float shape: [3,3,48,192] values: [[[-0.0759508833 -0.454142034 0.168537453...]]]...>
# unknown_40 (Const): [], value=Tensor<type: float shape: [48] values: 0.686095595 0.986479044 0.708781302...>
# unknown_39 (Const): [], value=Tensor<type: float shape: [48] values: 0.0244836491 0.953389 0.711678088...>
# unknown_38 (Const): [], value=Tensor<type: float shape: [48] values: 0.101757742 0.397758365 1.30003905...>
# unknown_37 (Const): [], value=Tensor<type: float shape: [48] values: 1.03099453 1.19108343 1.50210476...>
# unknown_36 (Const): [], value=Tensor<type: float shape: [1,1,48,48] values: [[[-0.456339866 0.0722245127 0.194181666...]]]...>
# unknown_35 (Const): [], value=Tensor<type: float shape: [48] values: 128.127167 99.2628555 76.0288544...>
# unknown_34 (Const): [], value=Tensor<type: float shape: [48] values: -11.9639864 0.58000654 7.65859318...>
# unknown_33 (Const): [], value=Tensor<type: float shape: [48] values: -0.37666586 -0.655849934 0.00286450959...>
# unknown_32 (Const): [], value=Tensor<type: float shape: [48] values: 1.11093771 0.915291846 0.831518114...>
# unknown_31 (Const): [], value=Tensor<type: float shape: [3,3,48,48] values: [[[-0.269819617 -0.0227318536 0.357860804...]]]...>
# unknown_30 (Const): [], value=Tensor<type: float shape: [48] values: 1.91040981 2.82001925 2.55128551...>
# unknown_29 (Const): [], value=Tensor<type: float shape: [48] values: 1.78687882 0.595485508 0.363452196...>
# unknown_28 (Const): [], value=Tensor<type: float shape: [48] values: -0.125172406 0.146426201 0.427877754...>
# unknown_27 (Const): [], value=Tensor<type: float shape: [48] values: 1.10068023 1.13089788 1.19280648...>
# unknown_26 (Const): [], value=Tensor<type: float shape: [1,1,48,48] values: [[[0.210722283 -0.110171124 -0.454534...]]]...>
# unknown_25 (Const): [], value=Tensor<type: float shape: [48] values: 59.3188896 37.1688118 25.0588245...>
# unknown_24 (Const): [], value=Tensor<type: float shape: [48] values: 13.1672258 -4.5945425 -1.7260915...>
# unknown_23 (Const): [], value=Tensor<type: float shape: [48] values: 0.825556397 0.341858715 -0.705210567...>
# unknown_22 (Const): [], value=Tensor<type: float shape: [48] values: 1.27666855 0.856479347 1.00565171...>
# unknown_21 (Const): [], value=Tensor<type: float shape: [3,3,48,48] values: [[[0.388473183 -0.0906179398 -0.0502412505...]]]...>
# unknown_20 (Const): [], value=Tensor<type: float shape: [48] values: 1.05305815 2.10795522 2.82550049...>
# unknown_19 (Const): [], value=Tensor<type: float shape: [48] values: -0.994696259 -2.03536749 2.08292...>
# unknown_18 (Const): [], value=Tensor<type: float shape: [48] values: 0.603450119 -0.997992337 0.409303755...>
# unknown_17 (Const): [], value=Tensor<type: float shape: [48] values: 0.628233612 1.12677157 0.98868835...>
# unknown_16 (Const): [], value=Tensor<type: float shape: [1,1,48,48] values: [[[-0.0567615144 -0.446242094 -0.102973387...]]]...>
# unknown_15 (Const): [], value=Tensor<type: float shape: [48] values: 25.3048 24.8785057 8.60026836...>
# unknown_14 (Const): [], value=Tensor<type: float shape: [48] values: -5.46312571 1.14147329 2.94183254...>
# unknown_13 (Const): [], value=Tensor<type: float shape: [48] values: 0.826804519 2.03006983 1.07072091...>
# unknown_12 (Const): [], value=Tensor<type: float shape: [48] values: 0.744499505 0.822506964 0.598431408...>
# unknown_11 (Const): [], value=Tensor<type: float shape: [3,3,24,48] values: [[[-0.303743 -0.746751308 -0.174465671...]]]...>
# unknown_10 (Const): [], value=Tensor<type: float shape: [24] values: 0.236920297 0.0421953537 -0.341613919...>
# unknown_9 (Const): [], value=Tensor<type: float shape: [1,1,48,24] values: [[[0.0298350602 0.213390976 -0.0633942485...]]]...>
# unknown_8 (Const): [], value=Tensor<type: float shape: [24] values: 296.941559 4.05193949 1.08724141...>
# unknown_7 (Const): [], value=Tensor<type: float shape: [24] values: 6.94447374 -0.621721745 -0.434874147...>
# unknown_6 (Const): [], value=Tensor<type: float shape: [24] values: 0.384694576 -0.551071465 -0.691649497...>
# unknown_5 (Const): [], value=Tensor<type: float shape: [24] values: 1.33412218 1.49764514 1.06072474...>
# unknown_4 (Const): [], value=Tensor<type: float shape: [4,8,1,24] values: [[[0.0139002278 -0.174000353 -0.0141728045...]]]...>
# unknown_3 (Const): [], value=Tensor<type: float shape: [1] values: 0.931538701>
# unknown_2 (Const): [], value=Tensor<type: float shape: [1] values: 0.543906331>
# unknown_1 (Const): [], value=Tensor<type: float shape: [1] values: 0.638852>
# unknown_0 (Const): [], value=Tensor<type: float shape: [1] values: 1.66165364>
# unknown (Const): [], value=Tensor<type: float shape: [] values: 1.24819195>
# Func/StatefulPartitionedCall/output_control_node/_248 (NoOp): [^unknown, ^unknown_14, ^unknown_15, ^unknown_12, ^unknown_13, ^unknown_19, ^unknown_20, ^unknown_17, ^unknown_18, ^unknown_11, ^unknown_16, ^unknown_24, ^unknown_25, ^unknown_22, ^unknown_23, ^unknown_29, ^unknown_30, ^unknown_27, ^unknown_28, ^unknown_21, ^unknown_26, ^unknown_34, ^unknown_35, ^unknown_32, ^unknown_33, ^unknown_39, ^unknown_40, ^unknown_37, ^unknown_38, ^unknown_31, ^unknown_36, ^unknown_44, ^unknown_45, ^unknown_42, ^unknown_43, ^unknown_49, ^unknown_50, ^unknown_47, ^unknown_48, ^unknown_41, ^unknown_46, ^unknown_54, ^unknown_55, ^unknown_52, ^unknown_53, ^unknown_59, ^unknown_60, ^unknown_57, ^unknown_58, ^unknown_51, ^unknown_56, ^unknown_64, ^unknown_65, ^unknown_62, ^unknown_63, ^unknown_69, ^unknown_70, ^unknown_67, ^unknown_68, ^unknown_61, ^unknown_66, ^unknown_74, ^unknown_75, ^unknown_72, ^unknown_73, ^unknown_79, ^unknown_80, ^unknown_77, ^unknown_78, ^unknown_71, ^unknown_76, ^unknown_84, ^unknown_85, ^unknown_82, ^unknown_83, ^unknown_89, ^unknown_90, ^unknown_87, ^unknown_88, ^unknown_96, ^unknown_97, ^unknown_94, ^unknown_95, ^unknown_81, ^unknown_86, ^unknown_93, ^unknown_91, ^unknown_92, ^unknown_101, ^unknown_102, ^unknown_99, ^unknown_100, ^unknown_106, ^unknown_107, ^unknown_104, ^unknown_105, ^unknown_113, ^unknown_114, ^unknown_111, ^unknown_112, ^unknown_98, ^unknown_103, ^unknown_110, ^unknown_108, ^unknown_109, ^unknown_118, ^unknown_119, ^unknown_116, ^unknown_117, ^unknown_123, ^unknown_124, ^unknown_121, ^unknown_122, ^unknown_130, ^unknown_131, ^unknown_128, ^unknown_129, ^unknown_115, ^unknown_120, ^unknown_127, ^unknown_125, ^unknown_126, ^unknown_135, ^unknown_136, ^unknown_133, ^unknown_134, ^unknown_140, ^unknown_141, ^unknown_138, ^unknown_139, ^unknown_147, ^unknown_148, ^unknown_145, ^unknown_146, ^unknown_132, ^unknown_137, ^unknown_144, ^unknown_142, ^unknown_143, ^unknown_152, ^unknown_153, ^unknown_150, ^unknown_151, ^unknown_157, ^unknown_158, ^unknown_155, ^unknown_156, ^unknown_164, ^unknown_165, ^unknown_162, ^unknown_163, ^unknown_149, ^unknown_154, ^unknown_161, ^unknown_159, ^unknown_160, ^unknown_169, ^unknown_170, ^unknown_167, ^unknown_168, ^unknown_174, ^unknown_175, ^unknown_172, ^unknown_173, ^unknown_181, ^unknown_182, ^unknown_179, ^unknown_180, ^unknown_166, ^unknown_171, ^unknown_178, ^unknown_176, ^unknown_177, ^unknown_186, ^unknown_187, ^unknown_184, ^unknown_185, ^unknown_191, ^unknown_192, ^unknown_189, ^unknown_190, ^unknown_198, ^unknown_199, ^unknown_196, ^unknown_197, ^unknown_183, ^unknown_188, ^unknown_195, ^unknown_193, ^unknown_194, ^unknown_203, ^unknown_204, ^unknown_201, ^unknown_202, ^unknown_208, ^unknown_209, ^unknown_206, ^unknown_207, ^unknown_215, ^unknown_216, ^unknown_213, ^unknown_214, ^unknown_200, ^unknown_205, ^unknown_212, ^unknown_210, ^unknown_211, ^unknown_220, ^unknown_221, ^unknown_218, ^unknown_219, ^unknown_225, ^unknown_226, ^unknown_223, ^unknown_224, ^unknown_232, ^unknown_233, ^unknown_230, ^unknown_231, ^unknown_217, ^unknown_222, ^unknown_229, ^unknown_227, ^unknown_228, ^unknown_7, ^unknown_8, ^unknown_5, ^unknown_6, ^unknown_236, ^unknown_237, ^unknown_234, ^unknown_235, ^unknown_2, ^unknown_3, ^unknown_0, ^unknown_1, ^unknown_244, ^unknown_243, ^unknown_4, ^unknown_241, ^unknown_242, ^unknown_239, ^unknown_240, ^unknown_238, ^unknown_10, ^unknown_9]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/Exp (Exp): [unknown]
# inputs (Placeholder): []
# StatefulPartitionedCall/model/GLOBAL_AVG_POOL/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 896>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_4-4_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 896>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_4-3_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 896>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_4-2_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 896>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_4-1_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 512>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_3-5_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 512>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_3-4_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 512>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_3-3_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 512>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_3-2_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_RESHAPE/Reshape/shape/3 (Const): [], value=Tensor<type: int32 shape: [] values: 512>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_RESHAPE/Reshape/shape/2 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_RESHAPE/Reshape/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_RESHAPE/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_RESHAPE/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [1] values: 1>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_RESHAPE/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [1] values: 0>
# StatefulPartitionedCall/model/BLOCK_3-1_SE_AVG_POOL_1/Mean/reduction_indices (Const): [], value=Tensor<type: int32 shape: [2] values: 1 2>
# StatefulPartitionedCall/model/pool_0_CONCAT/concat/axis (Const): [], value=Tensor<type: int32 shape: [] values: 3>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/ExpandDims/dim (Const): [], value=Tensor<type: int32 shape: [] values: -1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/transpose/perm (Const): [], value=Tensor<type: int32 shape: [3] values: 0 2 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/add_1/x (Const): [], value=Tensor<type: float shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/add_1 (AddV2): [StatefulPartitionedCall/model/ADVANCED_SPEC1/add_1/x, StatefulPartitionedCall/model/ADVANCED_SPEC1/Exp]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/truediv_1/x (Const): [], value=Tensor<type: float shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/truediv_1 (RealDiv): [StatefulPartitionedCall/model/ADVANCED_SPEC1/truediv_1/x, StatefulPartitionedCall/model/ADVANCED_SPEC1/add_1]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/Pow/y (Const): [], value=Tensor<type: float shape: [] values: 2>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/strided_slice/stack_2 (Const): [], value=Tensor<type: int32 shape: [3] values: 1 1 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/strided_slice/stack_1 (Const): [], value=Tensor<type: int32 shape: [3] values: 0 0 128>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/strided_slice/stack (Const): [], value=Tensor<type: int32 shape: [3] values: 0 0 0>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/rfft/fft_length (Const): [], value=Tensor<type: int32 shape: [1] values: 512>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub_1/y (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/FloorMod/y (Const): [], value=Tensor<type: int32 shape: [] values: 2>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub/x (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/periodic (Const): [], value=Tensor<type: bool shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cast (Cast): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/periodic]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/range/delta (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/range/start (Const): [], value=Tensor<type: int32 shape: [] values: 0>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Const (Const): [], value=Tensor<type: float shape: [] values: 6.28318548>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul_2/x (Const): [], value=Tensor<type: float shape: [] values: 0.5>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub_2/x (Const): [], value=Tensor<type: float shape: [] values: 0.5>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/concat_2/axis (Const): [], value=Tensor<type: int32 shape: [] values: 0>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/Reshape_3/shape/0 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/range_2/delta (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/floordiv_1/y (Const): [], value=Tensor<type: int32 shape: [] values: 8>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/range_2/start (Const): [], value=Tensor<type: int32 shape: [] values: 0>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/Reshape_2/shape/1 (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/floordiv_2/y (Const): [], value=Tensor<type: int32 shape: [] values: 8>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/range_1/delta (Const): [], value=Tensor<type: int32 shape: [] values: 1>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame_step (Const): [], value=Tensor<type: int32 shape: [] values: 280>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/floordiv_2 (FloorDiv): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame_step, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame/floordiv_2/y]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame_length (Const): [], value=Tensor<type: int32 shape: [] values: 512>
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/FloorMod (FloorMod): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame_length, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/FloorMod/y]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub (Sub): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub/x, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/FloorMod]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul (Mul): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cast, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/add (AddV2): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame_length, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub_1 (Sub): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/add, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub_1/y]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cast_1 (Cast): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/sub_1]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/range (Range): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/range/start, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/frame_length, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/range/delta]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cast_2 (Cast): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/range]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul_1 (Mul): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Const, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cast_2]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/truediv (RealDiv): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul_1, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cast_1]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cos (Cos): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/truediv]
# StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul_2 (Mul): [StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/mul_2/x, StatefulPartitionedCall/model/ADVANCED_SPEC1/stft/hann_window/Cos]
# ...
# StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/Conv2D, StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/mul, StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_2/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_1/IdentityN, unknown_177]
# StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_2/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-1_MULTIPLY/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-1_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-1_SE_CONV_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-1_CONV_3/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-1_MULTIPLY/mul, unknown_178]
# StatefulPartitionedCall/model/BLOCK_4-1_BN_3/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-1_CONV_3/Conv2D, unknown_179, unknown_180, unknown_181, unknown_182]
# StatefulPartitionedCall/model/BLOCK_4-2_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-1_BN_3/FusedBatchNormV3, unknown_183]
# StatefulPartitionedCall/model/BLOCK_4-2_BN_1/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-2_CONV_1/Conv2D, unknown_184, unknown_185, unknown_186, unknown_187]
# StatefulPartitionedCall/model/BLOCK_4-2_ACT_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-2_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-2_ACT_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-2_BN_1/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-2_ACT_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-2_ACT_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-2_ACT_1/mul, StatefulPartitionedCall/model/BLOCK_4-2_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-2_CONV_2/depthwise (DepthwiseConv2dNative): [StatefulPartitionedCall/model/BLOCK_4-2_ACT_1/IdentityN, unknown_188]
# StatefulPartitionedCall/model/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-2_CONV_2/depthwise, unknown_189, unknown_190, unknown_191, unknown_192]
# StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/mul, StatefulPartitionedCall/model/BLOCK_4-2_BN_2_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_AVG_POOL_1/Mean (Mean): [StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-2_SE_AVG_POOL_1/Mean/reduction_indices]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Shape (Shape): [StatefulPartitionedCall/model/BLOCK_4-2_SE_AVG_POOL_1/Mean]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice (StridedSlice): [StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Shape, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice/stack, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice/stack_1, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice/stack_2]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape (Pack): [StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/strided_slice, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape/1, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape/2, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape/3]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape (Reshape): [StatefulPartitionedCall/model/BLOCK_4-2_SE_AVG_POOL_1/Mean, StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape/shape]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-2_SE_RESHAPE/Reshape, unknown_193]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/Conv2D, StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/mul, StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_2/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_1/IdentityN, unknown_194]
# StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_2/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-2_MULTIPLY/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-2_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-2_SE_CONV_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-2_CONV_3/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-2_MULTIPLY/mul, unknown_195]
# StatefulPartitionedCall/model/BLOCK_4-2_BN_3/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-2_CONV_3/Conv2D, unknown_196, unknown_197, unknown_198, unknown_199]
# StatefulPartitionedCall/model/BLOCK_4-2_ADD/add (AddV2): [StatefulPartitionedCall/model/BLOCK_4-2_BN_3/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-1_BN_3/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-3_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-2_ADD/add, unknown_200]
# StatefulPartitionedCall/model/BLOCK_4-3_BN_1/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-3_CONV_1/Conv2D, unknown_201, unknown_202, unknown_203, unknown_204]
# StatefulPartitionedCall/model/BLOCK_4-3_ACT_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-3_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-3_ACT_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-3_BN_1/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-3_ACT_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-3_ACT_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-3_ACT_1/mul, StatefulPartitionedCall/model/BLOCK_4-3_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-3_CONV_2/depthwise (DepthwiseConv2dNative): [StatefulPartitionedCall/model/BLOCK_4-3_ACT_1/IdentityN, unknown_205]
# StatefulPartitionedCall/model/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-3_CONV_2/depthwise, unknown_206, unknown_207, unknown_208, unknown_209]
# StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/mul, StatefulPartitionedCall/model/BLOCK_4-3_BN_2_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_AVG_POOL_1/Mean (Mean): [StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-3_SE_AVG_POOL_1/Mean/reduction_indices]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Shape (Shape): [StatefulPartitionedCall/model/BLOCK_4-3_SE_AVG_POOL_1/Mean]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice (StridedSlice): [StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Shape, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice/stack, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice/stack_1, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice/stack_2]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape (Pack): [StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/strided_slice, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape/1, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape/2, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape/3]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape (Reshape): [StatefulPartitionedCall/model/BLOCK_4-3_SE_AVG_POOL_1/Mean, StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape/shape]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-3_SE_RESHAPE/Reshape, unknown_210]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/Conv2D, StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/mul, StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_2/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_1/IdentityN, unknown_211]
# StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_2/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-3_MULTIPLY/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-3_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-3_SE_CONV_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-3_CONV_3/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-3_MULTIPLY/mul, unknown_212]
# StatefulPartitionedCall/model/BLOCK_4-3_BN_3/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-3_CONV_3/Conv2D, unknown_213, unknown_214, unknown_215, unknown_216]
# StatefulPartitionedCall/model/BLOCK_4-3_ADD/add (AddV2): [StatefulPartitionedCall/model/BLOCK_4-3_BN_3/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-2_ADD/add]
# StatefulPartitionedCall/model/BLOCK_4-4_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-3_ADD/add, unknown_217]
# StatefulPartitionedCall/model/BLOCK_4-4_BN_1/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-4_CONV_1/Conv2D, unknown_218, unknown_219, unknown_220, unknown_221]
# StatefulPartitionedCall/model/BLOCK_4-4_ACT_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-4_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-4_ACT_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-4_BN_1/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-4_ACT_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-4_ACT_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-4_ACT_1/mul, StatefulPartitionedCall/model/BLOCK_4-4_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-4_CONV_2/depthwise (DepthwiseConv2dNative): [StatefulPartitionedCall/model/BLOCK_4-4_ACT_1/IdentityN, unknown_222]
# StatefulPartitionedCall/model/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-4_CONV_2/depthwise, unknown_223, unknown_224, unknown_225, unknown_226]
# StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/mul, StatefulPartitionedCall/model/BLOCK_4-4_BN_2_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_AVG_POOL_1/Mean (Mean): [StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-4_SE_AVG_POOL_1/Mean/reduction_indices]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Shape (Shape): [StatefulPartitionedCall/model/BLOCK_4-4_SE_AVG_POOL_1/Mean]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice (StridedSlice): [StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Shape, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice/stack, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice/stack_1, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice/stack_2]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape (Pack): [StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/strided_slice, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape/1, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape/2, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape/3]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape (Reshape): [StatefulPartitionedCall/model/BLOCK_4-4_SE_AVG_POOL_1/Mean, StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape/shape]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-4_SE_RESHAPE/Reshape, unknown_227]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/Conv2D, StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/IdentityN (IdentityN): [StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/mul, StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_2/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_1/IdentityN, unknown_228]
# StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_2/Sigmoid (Sigmoid): [StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_2/Conv2D]
# StatefulPartitionedCall/model/BLOCK_4-4_MULTIPLY/mul (Mul): [StatefulPartitionedCall/model/BLOCK_4-4_ACT_2/IdentityN, StatefulPartitionedCall/model/BLOCK_4-4_SE_CONV_2/Sigmoid]
# StatefulPartitionedCall/model/BLOCK_4-4_CONV_3/Conv2D (Conv2D): [StatefulPartitionedCall/model/BLOCK_4-4_MULTIPLY/mul, unknown_229]
# StatefulPartitionedCall/model/BLOCK_4-4_BN_3/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-4_CONV_3/Conv2D, unknown_230, unknown_231, unknown_232, unknown_233]
# StatefulPartitionedCall/model/BLOCK_4-4_ADD/add (AddV2): [StatefulPartitionedCall/model/BLOCK_4-4_BN_3/FusedBatchNormV3, StatefulPartitionedCall/model/BLOCK_4-3_ADD/add]
# StatefulPartitionedCall/model/BNORM_POST_NOQUANT/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/BLOCK_4-4_ADD/add, unknown_234, unknown_235, unknown_236, unknown_237]
# StatefulPartitionedCall/model/ACT_POST/Relu (Relu): [StatefulPartitionedCall/model/BNORM_POST_NOQUANT/FusedBatchNormV3]
# StatefulPartitionedCall/model/POST_CONV_1/Conv2D (Conv2D): [StatefulPartitionedCall/model/ACT_POST/Relu, unknown_238]
# StatefulPartitionedCall/model/POST_BN_1/FusedBatchNormV3 (FusedBatchNormV3): [StatefulPartitionedCall/model/POST_CONV_1/Conv2D, unknown_239, unknown_240, unknown_241, unknown_242]
# StatefulPartitionedCall/model/POST_ACT_1/Relu (Relu): [StatefulPartitionedCall/model/POST_BN_1/FusedBatchNormV3]
# StatefulPartitionedCall/model/GLOBAL_AVG_POOL/Mean (Mean): [StatefulPartitionedCall/model/POST_ACT_1/Relu, StatefulPartitionedCall/model/GLOBAL_AVG_POOL/Mean/reduction_indices]
# StatefulPartitionedCall/model/CLASS_DENSE_1/MatMul (MatMul): [StatefulPartitionedCall/model/GLOBAL_AVG_POOL/Mean, unknown_243]
# StatefulPartitionedCall/model/CLASS_DENSE_1/BiasAdd (Add): [StatefulPartitionedCall/model/CLASS_DENSE_1/MatMul, unknown_244]

# %%
! python -m tf2onnx.convert \
  --input {opt_graph_v1} \
  --inputs inputs:0 \
  --outputs unknown_242:0,unknown_244:0 \
  --output {onnx_model_v1}
# Out:
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# WARNING:tensorflow:From /home/anthony/birdclef-2023/venv/lib/python3.10/site-packages/tf2onnx/tf_loader.py:302: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2023-02-26 05:37:39,160 - WARNING - From /home/anthony/birdclef-2023/venv/lib/python3.10/site-packages/tf2onnx/tf_loader.py:302: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# WARNING:tensorflow:From /home/anthony/birdclef-2023/venv/lib/python3.10/site-packages/tensorflow/python/framework/convert_to_constants.py:943: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2023-02-26 05:37:39,160 - WARNING - From /home/anthony/birdclef-2023/venv/lib/python3.10/site-packages/tensorflow/python/framework/convert_to_constants.py:943: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2023-02-26 05:37:39,171 - INFO - Using tensorflow=2.11.0, onnx=1.12.0, tf2onnx=1.13.0/2c1db5
# 2023-02-26 05:37:39,172 - INFO - Using opset <onnx, 13>
# 2023-02-26 05:37:39,174 - INFO - Computed 0 values for constant folding
# 2023-02-26 05:37:39,177 - INFO - Optimizing ONNX model
# 2023-02-26 05:37:39,185 - INFO - After optimization: Identity -2 (2->0)
# 2023-02-26 05:37:39,185 - INFO -
# 2023-02-26 05:37:39,185 - INFO - Successfully converted TensorFlow model ../data/models/birdnet-opt-v1.pb to ONNX
# 2023-02-26 05:37:39,185 - INFO - Model inputs: ['inputs:0']
# 2023-02-26 05:37:39,185 - INFO - Model outputs: ['unknown_242:0', 'unknown_244:0']
# 2023-02-26 05:37:39,185 - INFO - ONNX model is saved at ../data/models/birdnet-onnx-v1.onnx

# %%
import onnxruntime as rt
import numpy as np

test = np.random.randn(1, 144_000).astype(np.float32)

sess = rt.InferenceSession(onnx_model_v1)
y1 = sess.run(None, {"inputs:0": test})[0]

# %% [markdown]
# - https://leimao.github.io/blog/Save-Load-Inference-From-TF2-Frozen-Graph/
#
# We re-use a bit of code found from a random blog post.
# We basically want to use the frozen graph to do inference, because it has the same node names as the output onnx graph.
# We could use the saved_model directly, but we would need to make sure to get the correct embedding layer from it.

# %%
def wrap_frozen_graph(graph_def, inputs, outputs):
    def _imports_graph_def():
        tf.compat.v1.import_graph_def(graph_def, name="")

    wrapped_import = tf.compat.v1.wrap_function(_imports_graph_def, [])
    import_graph = wrapped_import.graph

    return wrapped_import.prune(
        tf.nest.map_structure(import_graph.as_graph_element, inputs),
        tf.nest.map_structure(import_graph.as_graph_element, outputs),
    )


# load optimized graph
with tf.io.gfile.GFile(opt_graph_v1, "rb") as f:
    graph_def = tf.compat.v1.GraphDef()
    graph_def.ParseFromString(f.read())

opt_tf_model = wrap_frozen_graph(graph_def, inputs="inputs:0", outputs="unknown_242:0")
tensor = tf.convert_to_tensor(test)
y2 = opt_tf_model(tensor).numpy()

# %%
y1.shape, y2.shape
# Out:
# ((320,), (320,))

# %%
np.allclose(y1, y2)
# Out:
# True

# %%
for i in range(100):
    test = np.random.randn(1, 144_000).astype(np.float32)
    y1 = sess.run(None, {"inputs:0": test})[0]
    y2 = opt_tf_model(tensor).numpy()
    assert np.allclose(y1, y2)
print("ok")
# Out:
# ok
